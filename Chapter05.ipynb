# %% [markdown]
# <a href="https://colab.research.google.com/github/lifeisawavesorideit/99_LEARN_jvns_pandas-cookbook/blob/master/Chapter05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 3)
plt.rcParams['font.family'] = 'sans-serif'

# %% [markdown]
# # Summary

# %%
CSV_PATH = 'https://raw.githubusercontent.com/lifeisawavesorideit/99_LEARN_jvns_pandas-cookbook/master/data/weather_2012.csv'

# %%
weather_2012_final = pd.read_csv(CSV_PATH, sep=',', parse_dates=['Date/Time'], index_col='Date/Time')
weather_2012_final
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
# ...                       ...                 ...          ...
# 2012-12-31 19:00:00       0.1                -2.7           81
# 2012-12-31 20:00:00       0.2                -2.4           83
# 2012-12-31 21:00:00      -0.5                -1.5           93
# 2012-12-31 22:00:00      -0.2                -1.8           89
# 2012-12-31 23:00:00       0.0                -2.1           86
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# ...

# %%
weather_2012_final.dtypes
# Out:
# Temp (C)              float64
# Dew Point Temp (C)    float64
# Rel Hum (%)             int64
# Wind Spd (km/h)         int64
# Visibility (km)       float64
# Stn Press (kPa)       float64
# Weather                object
# dtype: object

# %%
weather_2012_final['Temp (C)'].plot(figsize=(15, 6))

# %% [markdown]
# #5.1 Downloading one month of weather data

# %%
URL_TEMPLATE = "http://climate.weather.gc.ca/climateData/bulkdata_e.html?format=csv&stationID=5415&Year={year}&Month={month}&timeframe=1&submit=Download+Data"

# %%
url_weather_mar2012 = URL_TEMPLATE.format(month=3, year=2012)
url_weather_mar2012
# Out:
# 'http://climate.weather.gc.ca/climateData/bulkdata_e.html?format=csv&stationID=5415&Year=2012&Month=3&timeframe=1&submit=Download+Data'

# %%
weather_mar2012 = pd.read_csv(url_weather_mar2012)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-12-7978ac53af62> in <module>
# ----> 1 weather_mar2012 = pd.read_csv(url_weather_mar2012)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
